# %%
import os
import random
import json
import time
from google.cloud import pubsub_v1
from google.cloud import storage
from google.cloud.storage import Blob
import xml.etree.ElementTree as ET
import argparse
import logging

# %%
data = [
    (-0.34924, 39.46126, 0),
    (-0.34954, 39.46136, 0),
    (-0.35008, 39.46154, 0),
    (-0.35114, 39.46185, 0),
    (-0.35152, 39.46197, 0),
    (-0.35246, 39.46227, 0),
    (-0.35247, 39.46227, 0),
    (-0.35266, 39.46232, 0),
    (-0.35269, 39.46225, 0),
    (-0.35309, 39.46129, 0),
    (-0.35333, 39.46065, 0),
    (-0.35335, 39.46065, 0),
    (-0.35337, 39.46065, 0),
    (-0.35339, 39.46065, 0),
    (-0.35341, 39.46065, 0),
    (-0.35343, 39.46065, 0),
    (-0.35345, 39.46065, 0),
    (-0.35347, 39.46065, 0),
    (-0.3535, 39.46065, 0),
    (-0.35355, 39.46064, 0),
    (-0.35361, 39.46063, 0),
    (-0.35367, 39.46061, 0),
    (-0.35373, 39.46059, 0),
    (-0.35378, 39.46056, 0),
    (-0.35383, 39.46053, 0),
    (-0.35387, 39.4605, 0),
    (-0.35391, 39.46046, 0),
    (-0.35394, 39.46042, 0),
    (-0.35397, 39.46038, 0),
    (-0.35399, 39.46033, 0),
    (-0.35401, 39.46029, 0),
    (-0.35402, 39.46024, 0),
    (-0.35402, 39.4602, 0),
    (-0.35402, 39.46015, 0),
    (-0.35401, 39.46012, 0),
    (-0.35401, 39.4601, 0),
    (-0.35399, 39.46006, 0),
    (-0.35397, 39.46001, 0),
    (-0.35394, 39.45996, 0),
    (-0.3539, 39.45992, 0),
    (-0.35386, 39.45988, 0),
    (-0.35381, 39.45985, 0),
    (-0.35376, 39.45981, 0),
    (-0.3537, 39.45979, 0),
    (-0.35376, 39.45965, 0),
    (-0.35377, 39.45963, 0)
]

# %%
pip install apache-beam
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: apache-beam in c:\users\josan\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.51.0)
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: C:\Users\josan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import random
import apache_beam as beam

def generar_posiciones_vehiculos(coordenadas):
    vehiculos = []
    # Iterar por la lista de coordenadas de los vehículos
    for i, coord_vehiculo in enumerate(coordenadas):
        mensaje_vehiculo = {"vehiculo"+str(i): coord_vehiculo}
        vehiculos.append(mensaje_vehiculo)
    return vehiculos

lista_mensajes_vehiculos = generar_posiciones_vehiculos(data)

# for mensaje in lista_mensajes_vehiculos:
#     print(mensaje)

# def generar_posiciones_solicitantes(coordenadas):
#     solicitudes = []
#     # Mezclar las coordenadas de los solicitantes aleatoriamente
#     coord_solicitante = coordenadas.copy()  # Hacemos una copia de los datos de los vehículos
#     random.shuffle(coord_solicitante)
#     for i, coord_solicitante in enumerate(coordenadas):
#         mensaje_solicitante = {"Solicitante"+str(i): coord_solicitante}
#         solicitudes.append(mensaje_solicitante)
#     return solicitudes

def generar_posiciones_solicitantes():
    solicitudes = [{"Solicitante unico": (-0.35386, 39.45988, 0)}]
    # Mezclar las coordenadas de los solicitantes aleatoriamente
       
    return solicitudes


lista_mensajes_solicitudes = generar_posiciones_solicitantes()



for mensaje2 in lista_mensajes_solicitudes:
    print(mensaje2)
# Out:
# {'Solicitante unico': (-0.35386, 39.45988, 0)}

# %%
# bucles para el dofn, accedemos a los valores de la tupla de coordenadas de ambos mensajes

for diccionario1 in lista_mensajes_vehiculos:
    # Obtener la tupla del diccionario y luego el segundo elemento de la tupla
    segundo_valor = list(diccionario1.values())[0]

    for diccionario2 in lista_mensajes_solicitudes:
        # Obtener la tupla del diccionario y luego el segundo elemento de la tupla
        segundo_valor2 = list(diccionario2.values())[0]

        # Comparar los segundos valores de las tuplas
        if segundo_valor == segundo_valor2:
            print("Los segundos valores son iguales:", segundo_valor)
        # else:
        #     print("Los segundos valores son diferentes:", segundo_valor, segundo_valor2)
# Out:
# Los segundos valores son iguales: (-0.35386, 39.45988, 0)

# %%
pip install apache-beam

# %%
import apache_beam as beam
from apache_beam.options.pipeline_options import PipelineOptions
from apache_beam.options.pipeline_options import PipelineOptions

pipeline_options = PipelineOptions(['--direct_running_mode=direct'])


class ProcesarMensajeVehiculo(beam.DoFn):
    def process(self, elemento1):
        # Aquí puedes realizar cualquier operación que necesites en cada elemento de la lista
        # Por ejemplo, imprimir el elemento
        # print(elemento)
        # O realizar cualquier otro procesamiento y emitir los resultados
        yield elemento1



# Ahora, puedes usar esta clase de DoFn en tu pipeline de Apache Beam
with beam.Pipeline() as pipeline:
    mensajes_vehiculos = (
        pipeline
        | "Generar Mensajes Vehículos" >> beam.Create(generar_posiciones_vehiculos(data))
        | "Procesar Mensajes Vehículos" >> beam.ParDo(ProcesarMensajeVehiculo())
        | "Imprimir Mensajes Vehiculos" >> beam.Map(print)
    )
# Out:
# {'vehiculo0': (-0.34924, 39.46126, 0)}
# {'vehiculo1': (-0.34954, 39.46136, 0)}
# {'vehiculo2': (-0.35008, 39.46154, 0)}
# {'vehiculo3': (-0.35114, 39.46185, 0)}
# {'vehiculo4': (-0.35152, 39.46197, 0)}
# {'vehiculo5': (-0.35246, 39.46227, 0)}
# {'vehiculo6': (-0.35247, 39.46227, 0)}
# {'vehiculo7': (-0.35266, 39.46232, 0)}
# {'vehiculo8': (-0.35269, 39.46225, 0)}
# {'vehiculo9': (-0.35309, 39.46129, 0)}
# {'vehiculo10': (-0.35333, 39.46065, 0)}
# {'vehiculo11': (-0.35335, 39.46065, 0)}
# {'vehiculo12': (-0.35337, 39.46065, 0)}
# {'vehiculo13': (-0.35339, 39.46065, 0)}
# {'vehiculo14': (-0.35341, 39.46065, 0)}
# {'vehiculo15': (-0.35343, 39.46065, 0)}
# {'vehiculo16': (-0.35345, 39.46065, 0)}
# {'vehiculo17': (-0.35347, 39.46065, 0)}
# {'vehiculo18': (-0.3535, 39.46065, 0)}
# {'vehiculo19': (-0.35355, 39.46064, 0)}
# {'vehiculo20': (-0.35361, 39.46063, 0)}
# {'vehiculo21': (-0.35367, 39.46061, 0)}
# {'vehiculo22': (-0.35373, 39.46059, 0)}
# {'vehiculo23': (-0.35378, 39.46056, 0)}
# ...

# %% [markdown]
# (-0.34924, 39.46126, 0),{'vehiculo0': (-0.34924, 39.46126, 0)}

# %%
import apache_beam as beam
from apache_beam.options.pipeline_options import PipelineOptions
from apache_beam.options.pipeline_options import PipelineOptions

pipeline_options = PipelineOptions(['--direct_running_mode=direct'])


class ProcesarMensajeVehiculo(beam.DoFn):
    def process(self, elemento1):
        # Aquí puedes realizar cualquier operación que necesites en cada elemento de la lista
        # Por ejemplo, imprimir el elemento
        # print(elemento)
        # O realizar cualquier otro procesamiento y emitir los resultados
        yield elemento1

class ProcesarMensajeSolictante(beam.DoFn):
    def process(self, elemento2):
        # Aquí puedes realizar cualquier operación que necesites en cada elemento de la lista
        # Por ejemplo, imprimir el elemento
        # print(elemento)
        # O realizar cualquier otro procesamiento y emitir los resultados
        yield elemento2


class MachearMensajes(beam.DoFn):
    
    
    def process(self, element, lista_mensajes_vehiculos, lista_mensajes_solicitudes):
        for diccionario1 in lista_mensajes_vehiculos:
            segundo_valor = list(diccionario1.values())[0]
            # print("Comparando con:", segundo_valor)
            for diccionario2 in lista_mensajes_solicitudes:
                segundo_valor2 = list(diccionario2.values())[0]
                # print("   Con:", segundo_valor2)
                if segundo_valor == segundo_valor2:
                    print("Coincidencia encontrada:", segundo_valor)
                    yield (segundo_valor, segundo_valor2)




        


# Ahora, puedes usar esta clase de DoFn en tu pipeline de Apache Beam
with beam.Pipeline() as pipeline:
    mensajes_vehiculos = (
        pipeline
        | "Generar Mensajes Vehículos" >> beam.Create(generar_posiciones_vehiculos(data))
        | "Procesar Mensajes Vehículos" >> beam.ParDo(ProcesarMensajeVehiculo())
        # | "Imprimir Mensajes Vehiculos" >> beam.Map(print)
    )
    mensajes_solicitudes = (
        pipeline
        | "Generar Mensajes solicitudes" >> beam.Create(generar_posiciones_solicitantes())
        | "Procesar Mensajes solicitudes" >> beam.ParDo(ProcesarMensajeSolictante())
        # | "Imprimir Mensajes solicitudes" >> beam.Map(print)
    )
    todosMensajes = ((mensajes_solicitudes, mensajes_vehiculos)
        | "Combinar Mensajes" >> beam.Flatten()
        | "Dofn matcheo" >> beam.ParDo(MachearMensajes(), 
                                        lista_mensajes_vehiculos=beam.pvalue.AsList(mensajes_vehiculos), 
                                        lista_mensajes_solicitudes=beam.pvalue.AsList(mensajes_solicitudes))
        | "Imprimir Resultados" >> beam.Map(print)
    )
# Out:
# Coincidencia encontrada: (-0.35386, 39.45988, 0)
# ((-0.35386, 39.45988, 0), (-0.35386, 39.45988, 0))
# Coincidencia encontrada: (-0.35386, 39.45988, 0)
# ((-0.35386, 39.45988, 0), (-0.35386, 39.45988, 0))
# Coincidencia encontrada: (-0.35386, 39.45988, 0)
# ((-0.35386, 39.45988, 0), (-0.35386, 39.45988, 0))
# Coincidencia encontrada: (-0.35386, 39.45988, 0)
# ((-0.35386, 39.45988, 0), (-0.35386, 39.45988, 0))
# Coincidencia encontrada: (-0.35386, 39.45988, 0)
# ((-0.35386, 39.45988, 0), (-0.35386, 39.45988, 0))
# Coincidencia encontrada: (-0.35386, 39.45988, 0)
# ((-0.35386, 39.45988, 0), (-0.35386, 39.45988, 0))
# Coincidencia encontrada: (-0.35386, 39.45988, 0)
# ((-0.35386, 39.45988, 0), (-0.35386, 39.45988, 0))
# Coincidencia encontrada: (-0.35386, 39.45988, 0)
# ((-0.35386, 39.45988, 0), (-0.35386, 39.45988, 0))
# Coincidencia encontrada: (-0.35386, 39.45988, 0)
# ((-0.35386, 39.45988, 0), (-0.35386, 39.45988, 0))
# Coincidencia encontrada: (-0.35386, 39.45988, 0)
# ...
